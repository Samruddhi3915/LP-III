# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/Users/sam/Desktop/ML PRS/PR1/uber.csv")

# %%
df
# Out:
#         Unnamed: 0                            key  fare_amount
# 0         24238194    2015-05-07 19:52:06.0000003          7.5  \
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 199995    42598914   2012-10-28 10:49:00.00000053          3.0
# 199996    16382965    2014-03-14 01:09:00.0000008          7.5
# 199997    27804658   2009-06-29 00:42:00.00000078         30.9
# 199998    20259894    2015-05-20 14:56:25.0000004         14.5
# 199999    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude
# 0       2015-05-07 19:52:06 UTC        -73.999817        40.738354  \
# 1       2009-07-17 20:04:56 UTC        -73.994355        40.728225
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
df.shape
# Out:
# (200000, 9)

# %%
df.head()
# Out:
#    Unnamed: 0                            key  fare_amount
# 0    24238194    2015-05-07 19:52:06.0000003          7.5  \
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354  \
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0                           key  fare_amount
# 199995    42598914  2012-10-28 10:49:00.00000053          3.0  \
# 199996    16382965   2014-03-14 01:09:00.0000008          7.5
# 199997    27804658  2009-06-29 00:42:00.00000078         30.9
# 199998    20259894   2015-05-20 14:56:25.0000004         14.5
# 199999    11951496  2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude
# 199995  2012-10-28 10:49:00 UTC        -73.987042        40.739367  \
# 199996  2014-03-14 01:09:00 UTC        -73.984722        40.736837
# 199997  2009-06-29 00:42:00 UTC        -73.986017        40.756487
# 199998  2015-05-20 14:56:25 UTC        -73.997124        40.725452
# 199999  2010-05-15 04:08:00 UTC        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# 199995         -73.986525         40.740297                1
# 199996         -74.006672         40.739620                1
# ...

# %%
df.isnull()
# Out:
#         Unnamed: 0    key  fare_amount  pickup_datetime  pickup_longitude
# 0            False  False        False            False             False  \
# 1            False  False        False            False             False
# 2            False  False        False            False             False
# 3            False  False        False            False             False
# 4            False  False        False            False             False
# ...            ...    ...          ...              ...               ...
# 199995       False  False        False            False             False
# 199996       False  False        False            False             False
# 199997       False  False        False            False             False
# 199998       False  False        False            False             False
# 199999       False  False        False            False             False
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# key                   object
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
df['dropoff_longitude'].fillna(value=df['dropoff_longitude'].mean,inplace=True)
df['dropoff_latitude'].fillna(value=df['dropoff_latitude'].mean,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# dtype: int64

# %%
df['pickup_datetime']=pd.to_datetime(df['pickup_datetime'])

# %%
df.dtypes
# Out:
# Unnamed: 0                         int64
# key                               object
# fare_amount                      float64
# pickup_datetime      datetime64[ns, UTC]
# pickup_longitude                 float64
# pickup_latitude                  float64
# dropoff_longitude                 object
# dropoff_latitude                  object
# passenger_count                    int64
# dtype: object

# %%
df['dropoff_longitude']=pd.to_numeric(df['dropoff_longitude'],errors='coerce')
df['dropoff_latitude']=pd.to_numeric(df['dropoff_latitude'],errors='coerce')

df.dtypes
# Out:
# Unnamed: 0                         int64
# key                               object
# fare_amount                      float64
# pickup_datetime      datetime64[ns, UTC]
# pickup_longitude                 float64
# pickup_latitude                  float64
# dropoff_longitude                float64
# dropoff_latitude                 float64
# passenger_count                    int64
# dtype: object

# %%
df=df.assign(hour=df['pickup_datetime'].dt.hour,
            day=df['pickup_datetime'].dt.day,
            month=df['pickup_datetime'].dt.month,
            year=df['pickup_datetime'].dt.year,
            dayofweek=df['pickup_datetime'].dt.dayofweek)

# %%
df
# Out:
#         Unnamed: 0                            key  fare_amount
# 0         24238194    2015-05-07 19:52:06.0000003          7.5  \
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 199995    42598914   2012-10-28 10:49:00.00000053          3.0
# 199996    16382965    2014-03-14 01:09:00.0000008          7.5
# 199997    27804658   2009-06-29 00:42:00.00000078         30.9
# 199998    20259894    2015-05-20 14:56:25.0000004         14.5
# 199999    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                  pickup_datetime  pickup_longitude  pickup_latitude
# 0      2015-05-07 19:52:06+00:00        -73.999817        40.738354  \
# 1      2009-07-17 20:04:56+00:00        -73.994355        40.728225
# ...

# %%
df.drop(['pickup_datetime'],axis=1)
# Out:
#         Unnamed: 0                            key  fare_amount
# 0         24238194    2015-05-07 19:52:06.0000003          7.5  \
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 199995    42598914   2012-10-28 10:49:00.00000053          3.0
# 199996    16382965    2014-03-14 01:09:00.0000008          7.5
# 199997    27804658   2009-06-29 00:42:00.00000078         30.9
# 199998    20259894    2015-05-20 14:56:25.0000004         14.5
# 199999    11951496   2010-05-15 04:08:00.00000076         14.1
#
#         pickup_longitude  pickup_latitude  dropoff_longitude
# 0             -73.999817        40.738354         -73.999512  \
# 1             -73.994355        40.728225         -73.994710
# ...

# %%
from math import *
def distance_formula(longitude1,latitude1,longitude2,latitude2):
    travel_distance=[]
    for pos in range(len(longitude1)):
        lon1,lat1,lon2,lat2=map(radians,[longitude1[pos],latitude1[pos],longitude2[pos],latitude2[pos]])
        dist_lon=lon2-lon1
        dist_lat=lat2-lat1
        a=sin(dist_lat/2)**2+cos(lat1)*cos(lat2)*sin(dist_lon/2)**2
        c=2*asin(sqrt(a))*6371
        travel_distance.append(c)
    return travel_distance

# %%
df['travel_distance']=distance_formula(df['pickup_longitude'].to_numpy(),df['pickup_latitude'].to_numpy(),df['dropoff_longitude'].to_numpy(),df['dropoff_latitude'].to_numpy())

# %%
df
# Out:
#         Unnamed: 0                            key  fare_amount
# 0         24238194    2015-05-07 19:52:06.0000003          7.5  \
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 199995    42598914   2012-10-28 10:49:00.00000053          3.0
# 199996    16382965    2014-03-14 01:09:00.0000008          7.5
# 199997    27804658   2009-06-29 00:42:00.00000078         30.9
# 199998    20259894    2015-05-20 14:56:25.0000004         14.5
# 199999    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                  pickup_datetime  pickup_longitude  pickup_latitude
# 0      2015-05-07 19:52:06+00:00        -73.999817        40.738354  \
# 1      2009-07-17 20:04:56+00:00        -73.994355        40.728225
# ...

# %%
df.plot(kind="box",subplots=True,layout=(7,2),figsize=(15,20))
plt.show()

# %%
df=df.drop(['key'],axis=1)

# %%
for col in df:
    q1=df[col].quantile(0.25)
    q3=df[col].quantile(0.75)
    IQR=q3-q1
    low=q1-1.5*IQR
    high=q3+1.5*IQR
    df[col]=np.clip(df[col],low,high)

# %%
df.dtypes
# Out:
# Unnamed: 0                         int64
# fare_amount                      float64
# pickup_datetime      datetime64[ns, UTC]
# pickup_longitude                 float64
# pickup_latitude                  float64
# dropoff_longitude                float64
# dropoff_latitude                 float64
# passenger_count                  float64
# hour                               int32
# day                                int32
# month                              int32
# year                               int32
# dayofweek                          int32
# travel_distance                  float64
# dtype: object

# %%
df.plot(kind="box",subplots=True,layout=(7,2),figsize=(15,20))
# Out:
# Unnamed: 0              Axes(0.125,0.786098;0.352273x0.0939024)
# fare_amount          Axes(0.547727,0.786098;0.352273x0.0939024)
# pickup_longitude        Axes(0.125,0.673415;0.352273x0.0939024)
# pickup_latitude      Axes(0.547727,0.673415;0.352273x0.0939024)
# dropoff_longitude       Axes(0.125,0.560732;0.352273x0.0939024)
# dropoff_latitude     Axes(0.547727,0.560732;0.352273x0.0939024)
# passenger_count         Axes(0.125,0.448049;0.352273x0.0939024)
# hour                 Axes(0.547727,0.448049;0.352273x0.0939024)
# day                     Axes(0.125,0.335366;0.352273x0.0939024)
# month                Axes(0.547727,0.335366;0.352273x0.0939024)
# year                    Axes(0.125,0.222683;0.352273x0.0939024)
# dayofweek            Axes(0.547727,0.222683;0.352273x0.0939024)
# travel_distance             Axes(0.125,0.11;0.352273x0.0939024)
# dtype: object

# %%
corr=df.corr
corr
# Out:
# <bound method DataFrame.corr of         Unnamed: 0  fare_amount           pickup_datetime  pickup_longitude
# 0         24238194         7.50 2015-05-07 19:52:06+00:00        -73.999817  \
# 1         27835199         7.70 2009-07-17 20:04:56+00:00        -73.994355
# 2         44984355        12.90 2009-08-24 21:45:00+00:00        -74.005043
# 3         25894730         5.30 2009-06-26 08:22:21+00:00        -73.976124
# 4         17610152        16.00 2014-08-28 17:47:00+00:00        -73.929786
# ...            ...          ...                       ...               ...
# 199995    42598914         3.00 2012-10-28 10:49:00+00:00        -73.987042
# 199996    16382965         7.50 2014-03-14 01:09:00+00:00        -73.984722
# 199997    27804658        22.25 2009-06-29 00:42:00+00:00        -73.986017
# 199998    20259894        14.50 2015-05-20 14:56:25+00:00        -73.997124
# 199999    11951496        14.10 2010-05-15 04:08:00+00:00        -73.984395
#
# ...

# %%
fig,axis=plt.subplots(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'fare_amount', 'pickup_datetime', 'pickup_longitude',
#        'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude',
#        'passenger_count', 'hour', 'day', 'month', 'year', 'dayofweek',
#        'travel_distance'],
#       dtype='object')

# %%
df_x=df[['travel_distance']]

# %%
df_y=df[['fare_amount']]

# %%
from sklearn.model_selection import train_test_split

# %%
df.dtypes
# Out:
# Unnamed: 0                         int64
# fare_amount                      float64
# pickup_datetime      datetime64[ns, UTC]
# pickup_longitude                 float64
# pickup_latitude                  float64
# dropoff_longitude                float64
# dropoff_latitude                 float64
# passenger_count                  float64
# hour                               int32
# day                                int32
# month                              int32
# year                               int32
# dayofweek                          int32
# travel_distance                  float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# hour                 0
# day                  0
# month                0
# year                 0
# dayofweek            0
# travel_distance      0
# dtype: int64

# %%
df['travel_distance'].fillna(value=df['travel_distance'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# hour                 0
# day                  0
# month                0
# year                 0
# dayofweek            0
# travel_distance      0
# dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(df_x,df_y,test_size=0.33,random_state=1)

# %%
df
# Out:
#         Unnamed: 0  fare_amount           pickup_datetime  pickup_longitude
# 0         24238194         7.50 2015-05-07 19:52:06+00:00        -73.999817  \
# 1         27835199         7.70 2009-07-17 20:04:56+00:00        -73.994355
# 2         44984355        12.90 2009-08-24 21:45:00+00:00        -74.005043
# 3         25894730         5.30 2009-06-26 08:22:21+00:00        -73.976124
# 4         17610152        16.00 2014-08-28 17:47:00+00:00        -73.929786
# ...            ...          ...                       ...               ...
# 199995    42598914         3.00 2012-10-28 10:49:00+00:00        -73.987042
# 199996    16382965         7.50 2014-03-14 01:09:00+00:00        -73.984722
# 199997    27804658        22.25 2009-06-29 00:42:00+00:00        -73.986017
# 199998    20259894        14.50 2015-05-20 14:56:25+00:00        -73.997124
# 199999    11951496        14.10 2010-05-15 04:08:00+00:00        -73.984395
#
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lin=LinearRegression()

# %%
lin.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lin.predict(x_test)
print(pred)
# Out:
# [[ 5.21460197]
#  [ 6.26126953]
#  [ 8.55476608]
#  ...
#  [ 5.51358039]
#  [ 8.36450802]
#  [20.4194087 ]]

# %%
from sklearn import metrics
from sklearn.metrics import r2_score

# %%
RMSE=np.sqrt(metrics.mean_squared_error(y_test,pred))
r2score=r2_score(y_test,pred)

# %%
full_metrics=pd.Series({"model":"Linear regression","RMSE":RMSE,"r2score":r2score})

# %%
print(full_metrics)
# Out:
# model      Linear regression
# RMSE                2.915867
# r2score             0.714192
# dtype: object

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
reg=RandomForestRegressor(n_estimators=100)

# %%
reg.fit(x_train,y_train)
# Out:
# /var/folders/r3/fmgksws93r95hsmnd4qp5ssr0000gn/T/ipykernel_95169/310678519.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   reg.fit(x_train,y_train)
# RandomForestRegressor()

# %%
pred=reg.predict(x_test)
print(pred)
# Out:
# [ 5.264      8.632      8.83      ...  4.097      7.604     21.1816444]

# %%
RMSE=np.sqrt(metrics.mean_squared_error(y_test,pred))
r2score=r2_score(y_test,pred)

# %%
print(RMSE)
# Out:
# 3.155361232088515

# %%
print(r2score)
# Out:
# 0.6653140324128038

# %%
full_metrics1=pd.Series({"Model":"RandomForestRegressor","RMSE":RMSE,"r2score":r2score})

# %%
print(full_metrics1)
# Out:
# Model      RandomForestRegressor
# RMSE                    3.155361
# r2score                 0.665314
# dtype: object
